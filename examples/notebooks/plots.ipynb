# %%
from lvreader import read_buffer
import matplotlib.pyplot as plt
from pprint import pprint
# %matplotlib notebook

# %%
with read_set("data/word_masked") as image_set:
    image_buffer = image_set[0]

# %%
pprint(image_buffer.attributes)
# Out:
# {'AttributeDisplayFrameInfo': 'SetupDialogBufferAttrFrameInfo(-1)',
#  'FastStorageStartTime': '22463.467724',
#  'LoadFile': 'data\\word_masked\\B00001.im7',
#  'LoadSet': 'data/word_masked',
#  'LoadSetIndex': '1',
#  '_DaVisVersion': 'MainLine.Developer.Build',
#  '_Date': '14.10.04',
#  '_FrameScale': '1\n0\nframe\n',
#  '_Header_PackType': '1',
#  '_Time': '17:34:36.906'}

# %%
image_frame = image_buffer[0]
pprint(image_frame.attributes)
# Out:
# {'Acq.Time': array([[500.]]),
#  'AcqTimeSeries': '1530749 µs',
#  'CCDExposureTime': '30000 µs',
#  'CamPixelSize': '6.45 µm',
#  'CameraName': '1A: Imager Intense (1376 x 1040 pixel)',
#  'FrameProcessing': '0'}

# %%
image_buffer.plot()
# Out:
# <img src="data:image/png;base64,..." width="572.85">

# %%
with read_set("data/2d3c") as vector_set:
    vector_buffer = vector_set[0]

vector_buffer.plot()
# Out:
# <img src="data:image/png;base64,..." width="572.85">

# %%
choice = vector_buffer.frames[0].active_choice[0]
fig, ax = plt.subplots()
im = ax.imshow(choice)
colorbar = fig.colorbar(im, values=[0,1,2,3], ticks=[0,1,2,3])
# Out:
# <img src="data:image/png;base64,..." width="572.85">
